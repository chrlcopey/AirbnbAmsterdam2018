# %% [markdown]
# # 6.1: Sourcing Open Data

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# path 
path = '/Users/LuisD/Documents/CareerFoundry/Achievement 6/AIR BNB Analysis'

# %%
#import
df = pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'listings.csv'), index_col = False)

# %%
df.head()
# Out:
#       id                                               name  host_id  \
# 0   2818           Quiet Garden View Room & Super Fast WiFi     3159
# 1   3209                  Quiet apt near center, great view     3806
# 2  20168         100%Centre-Studio 1 Private Floor/Bathroom    59484
# 3  25428                Lovely apt in City Centre (Jordaan)    56142
# 4  27886  Romantic, stylish B&B houseboat in canal district    97647
#
#   host_name  neighbourhood_group                           neighbourhood  \
# 0    Daniel                  NaN  Oostelijk Havengebied - Indische Buurt
# 1   Maartje                  NaN                              Westerpark
# 2      Alex                  NaN                            Centrum-Oost
# 3      Joan                  NaN                            Centrum-West
# 4      Flip                  NaN                            Centrum-West
#
#     latitude  longitude        room_type  price  minimum_nights  \
# ...

# %%
#basic information about the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20030 entries, 0 to 20029
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20030 non-null  int64
#  1   name                            19992 non-null  object
#  2   host_id                         20030 non-null  int64
#  3   host_name                       20026 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   20030 non-null  object
#  6   latitude                        20030 non-null  float64
#  7   longitude                       20030 non-null  float64
#  8   room_type                       20030 non-null  object
#  9   price                           20030 non-null  int64
#  10  minimum_nights                  20030 non-null  int64
#  11  number_of_reviews               20030 non-null  int64
# ...

# %%
df.shape
# Out:
# (20030, 16)

# %%
#import data set
df_calendar = pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'calendar.csv'), index_col = False)

# %%
df_calendar.head()
# Out:
#    listing_id        date available price
# 0        2818  2019-12-05         f   NaN
# 1       73208  2019-08-30         f   NaN
# 2       73208  2019-08-29         f   NaN
# 3       73208  2019-08-28         f   NaN
# 4       73208  2019-08-27         f   NaN

# %%
df_calendar.tail()
# Out:
#          listing_id        date available    price
# 7310945    29979667  2018-12-11         t  $139.00
# 7310946    29979667  2018-12-10         t  $139.00
# 7310947    29979667  2018-12-09         t  $139.00
# 7310948    29979667  2018-12-08         t  $139.00
# 7310949    29979667  2018-12-07         t  $139.00

# %%
df_calendar.columns
# Out:
# Index(['listing_id', 'date', 'available', 'price'], dtype='object')

# %%
df_calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7310950 entries, 0 to 7310949
# Data columns (total 4 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   listing_id  int64
#  1   date        object
#  2   available   object
#  3   price       object
# dtypes: int64(1), object(3)
# memory usage: 223.1+ MB

# %%
df_calendar.shape
# Out:
# (7310950, 4)

# %%
#import data set
df_reviews = pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'reviews.csv'), index_col = False)

# %%
df_reviews.head()
# Out:
#    listing_id        date
# 0        2818  2009-03-30
# 1        2818  2009-04-24
# 2        2818  2009-05-03
# 3        2818  2009-05-18
# 4        2818  2009-05-25

# %%
df_reviews.shape
# Out:
# (431830, 2)

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 431830 entries, 0 to 431829
# Data columns (total 2 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   listing_id  431830 non-null  int64
#  1   date        431830 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 6.6+ MB

# %%
#import data set
df_reviewsdetails = pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'reviews_details.csv'), index_col = False)

# %%
df_reviewsdetails.shape
# Out:
# (431830, 6)

# %%
df_reviewsdetails.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 431830 entries, 0 to 431829
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   listing_id     431830 non-null  int64
#  1   id             431830 non-null  int64
#  2   date           431830 non-null  object
#  3   reviewer_id    431830 non-null  int64
#  4   reviewer_name  431830 non-null  object
#  5   comments       431296 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 19.8+ MB

# %%
#import data set
df_neigbor = pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'neighbourhoods.csv'), index_col = False)

# %%
df_neigbor.shape
# Out:
# (22, 2)

# %%
df_neigbor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   neighbourhood_group  0 non-null      float64
#  1   neighbourhood        22 non-null     object
# dtypes: float64(1), object(1)
# memory usage: 484.0+ bytes

# %%
#import data set
df_ld = pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'listings_details.csv'), index_col = False)
# Out:
# /var/folders/l6/6xtwqmpx0rsb9tx3k_scftwm0000gp/T/ipykernel_51473/1624847299.py:1: DtypeWarning: Columns (87) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ld = pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'listings_details.csv'), index_col = False)

# %%
df_ld.shape
# Out:
# (20030, 96)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20030 entries, 0 to 20029
# Data columns (total 96 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                20030 non-null  int64
#  1   listing_url                       20030 non-null  object
#  2   scrape_id                         20030 non-null  int64
#  3   last_scraped                      20030 non-null  object
#  4   name                              19992 non-null  object
#  5   summary                           19510 non-null  object
#  6   space                             14579 non-null  object
#  7   description                       19906 non-null  object
#  8   experiences_offered               20030 non-null  object
#  9   neighborhood_overview             13257 non-null  object
#  10  notes                             9031 non-null   object
# ...

# %%
df.describe()
# Out:
#                  id       host_id  neighbourhood_group      latitude  \
# count  2.003000e+04  2.003000e+04                  0.0  20030.000000
# mean   1.541725e+07  4.868570e+07                  NaN     52.365212
# std    8.569404e+06  5.649635e+07                  NaN      0.015996
# min    2.818000e+03  3.159000e+03                  NaN     52.288378
# 25%    8.188423e+06  8.093516e+06                  NaN     52.355126
# 50%    1.563049e+07  2.369450e+07                  NaN     52.364590
# 75%    2.202577e+07  6.827535e+07                  NaN     52.375074
# max    3.058041e+07  2.293612e+08                  NaN     52.424713
#
#           longitude         price  minimum_nights  number_of_reviews  \
# count  20030.000000  20030.000000    20030.000000       20030.000000
# mean       4.888977    152.181178        3.328707          21.560459
# std        0.035573    145.828976       12.537419          43.240292
# ...

# %%
df_calendar.describe()
# Out:
#          listing_id
# count  7.310950e+06
# mean   1.541725e+07
# std    8.569190e+06
# min    2.818000e+03
# 25%    8.187901e+06
# 50%    1.563049e+07
# 75%    2.202612e+07
# max    3.058041e+07

# %%
df_calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7310950 entries, 0 to 7310949
# Data columns (total 4 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   listing_id  int64
#  1   date        object
#  2   available   object
#  3   price       object
# dtypes: int64(1), object(3)
# memory usage: 223.1+ MB

# %%
df_calendar.tail()
# Out:
#          listing_id        date available    price
# 7310945    29979667  2018-12-11         t  $139.00
# 7310946    29979667  2018-12-10         t  $139.00
# 7310947    29979667  2018-12-09         t  $139.00
# 7310948    29979667  2018-12-08         t  $139.00
# 7310949    29979667  2018-12-07         t  $139.00

# %%
# remove the symbol $
df_calendar['price'] = df_calendar['price'].str.replace(r'[$€,]', '', regex=True).astype(float)

# %%
df_calendar.tail()
# Out:
#          listing_id        date available  price
# 7310945    29979667  2018-12-11         t  139.0
# 7310946    29979667  2018-12-10         t  139.0
# 7310947    29979667  2018-12-09         t  139.0
# 7310948    29979667  2018-12-08         t  139.0
# 7310949    29979667  2018-12-07         t  139.0

# %%
df_calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7310950 entries, 0 to 7310949
# Data columns (total 4 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   listing_id  int64
#  1   date        object
#  2   available   object
#  3   price       float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 223.1+ MB

# %%
# change dtype of date
df_calendar['date'] = pd.to_datetime(df_calendar['date'])

# %%
df_calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7310950 entries, 0 to 7310949
# Data columns (total 4 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   listing_id  int64
#  1   date        datetime64[ns]
#  2   available   object
#  3   price       float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 223.1+ MB

# %%
df_calendar.tail()
# Out:
#          listing_id       date available  price
# 7310945    29979667 2018-12-11         t  139.0
# 7310946    29979667 2018-12-10         t  139.0
# 7310947    29979667 2018-12-09         t  139.0
# 7310948    29979667 2018-12-08         t  139.0
# 7310949    29979667 2018-12-07         t  139.0

# %%
df_calendar.describe()
# Out:
#          listing_id                           date         price
# count  7.310950e+06                        7310950  1.200071e+06
# mean   1.541725e+07  2019-06-06 01:00:53.559662336  2.076556e+02
# min    2.818000e+03            2018-12-06 00:00:00  9.000000e+00
# 25%    8.187901e+06            2019-03-07 00:00:00  1.090000e+02
# 50%    1.563049e+07            2019-06-06 00:00:00  1.500000e+02
# 75%    2.202612e+07            2019-09-05 00:00:00  2.400000e+02
# max    3.058041e+07            2019-12-06 00:00:00  8.500000e+03
# std    8.569190e+06                            NaN  2.812379e+02

# %%
df_review.describe()

# %%
# change dtype of date
df_reviews['date'] = pd.to_datetime(df_reviews['date'])

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 431830 entries, 0 to 431829
# Data columns (total 2 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   listing_id  431830 non-null  int64
#  1   date        431830 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 6.6 MB

# %%
# change dtype of date
df_reviewsdetails['date'] = pd.to_datetime(df_reviewsdetails['date'])

# %%
df.tail()
# Out:
#              id                                              name   host_id  \
# 20025  30576148  Family House City + free Parking+garden (160 m2)  13399651
# 20026  30577727                 Home Sweet Home in Indische Buurt   1595885
# 20027  30578037            Amsterdam Cozy apartment nearby center  87866499
# 20028  30579673           Home Sweet Home for a Guest or a Couple   1595885
# 20029  30580413       Cosy two bedroom appartment near 'de Pijp'!  27212057
#
#       host_name  neighbourhood_group                           neighbourhood  \
# 20025   Marieke                  NaN                         Watergraafsmeer
# 20026     Evita                  NaN  Oostelijk Havengebied - Indische Buurt
# 20027   Tommaso                  NaN                                Oud-Oost
# 20028     Evita                  NaN  Oostelijk Havengebied - Indische Buurt
# 20029      Lisa                  NaN                 De Pijp - Rivierenbuurt
#
# ...

# %%
# Drop column
df = df.drop(columns=['neighbourhood_group'])

# %%
df.tail()
# Out:
#              id                                              name   host_id  \
# 20025  30576148  Family House City + free Parking+garden (160 m2)  13399651
# 20026  30577727                 Home Sweet Home in Indische Buurt   1595885
# 20027  30578037            Amsterdam Cozy apartment nearby center  87866499
# 20028  30579673           Home Sweet Home for a Guest or a Couple   1595885
# 20029  30580413       Cosy two bedroom appartment near 'de Pijp'!  27212057
#
#       host_name                           neighbourhood   latitude  longitude  \
# 20025   Marieke                         Watergraafsmeer  52.345999   4.952145
# 20026     Evita  Oostelijk Havengebied - Indische Buurt  52.362412   4.932467
# 20027   Tommaso                                Oud-Oost  52.362431   4.926912
# 20028     Evita  Oostelijk Havengebied - Indische Buurt  52.363780   4.932493
# 20029      Lisa                 De Pijp - Rivierenbuurt  52.346911   4.901932
#
# ...

# %%
# find missing values
df.isnull().sum()
# Out:
# id                                   0
# name                                38
# host_id                              0
# host_name                            4
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       2406
# reviews_per_month                 2406
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64

# %%
# Editing missing data
df.loc[df['name'].isna(), 'name'] = 'Unknown'

# %%
df['name'].isna().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                            4
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       2406
# reviews_per_month                 2406
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64

# %%
# Editing missing data
df.loc[df['host_name'].isna(), 'host_name'] = 'Unknown'

# %%
df.loc[df['last_review'].isna(), 'last_review'] = 'never reviewed'

# %%
df.loc[df['reviews_per_month'].isna(), 'reviews_per_month'] = '0'

# %%
# Checking changes 
df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
df_reviewsdetails.isnull().sum()
# Out:
# listing_id         0
# id                 0
# date               0
# reviewer_id        0
# reviewer_name      0
# comments         534
# dtype: int64

# %%
# Editing missing data
df_reviewsdetails.loc[df_reviewsdetails['comments'].isna(), 'comments'] = 'No comments given'

# %%
# Checking changes 
df_reviewsdetails.isnull().sum()
# Out:
# listing_id       0
# id               0
# date             0
# reviewer_id      0
# reviewer_name    0
# comments         0
# dtype: int64

# %%
df_neigbor.isnull().sum()
# Out:
# neighbourhood_group    22
# neighbourhood           0
# dtype: int64

# %%
df_neigbor.head(22)
# Out:
#     neighbourhood_group                           neighbourhood
# 0                   NaN                         Bijlmer-Centrum
# 1                   NaN                            Bijlmer-Oost
# 2                   NaN                           Bos en Lommer
# 3                   NaN                  Buitenveldert - Zuidas
# 4                   NaN                            Centrum-Oost
# 5                   NaN                            Centrum-West
# 6                   NaN                  De Aker - Nieuw Sloten
# 7                   NaN                  De Baarsjes - Oud-West
# 8                   NaN                 De Pijp - Rivierenbuurt
# 9                   NaN                   Gaasperdam - Driemond
# 10                  NaN                 Geuzenveld - Slotermeer
# 11                  NaN                IJburg - Zeeburgereiland
# 12                  NaN                              Noord-Oost
# 13                  NaN                              Noord-West
# ...

# %%
df_ld.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20030 entries, 0 to 20029
# Data columns (total 96 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                20030 non-null  int64
#  1   listing_url                       20030 non-null  object
#  2   scrape_id                         20030 non-null  int64
#  3   last_scraped                      20030 non-null  object
#  4   name                              19992 non-null  object
#  5   summary                           19510 non-null  object
#  6   space                             14579 non-null  object
#  7   description                       19906 non-null  object
#  8   experiences_offered               20030 non-null  object
#  9   neighborhood_overview             13257 non-null  object
#  10  notes                             9031 non-null   object
# ...

# %%
df_ld.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   2818   https://www.airbnb.com/rooms/2818  20181206172549   2018-12-06
# 1   3209   https://www.airbnb.com/rooms/3209  20181206172549   2018-12-06
# 2  20168  https://www.airbnb.com/rooms/20168  20181206172549   2018-12-06
# 3  25428  https://www.airbnb.com/rooms/25428  20181206172549   2018-12-06
# 4  27886  https://www.airbnb.com/rooms/27886  20181206172549   2018-12-06
#
#                                                 name  \
# 0           Quiet Garden View Room & Super Fast WiFi
# 1                  Quiet apt near center, great view
# 2         100%Centre-Studio 1 Private Floor/Bathroom
# 3                Lovely apt in City Centre (Jordaan)
# 4  Romantic, stylish B&B houseboat in canal district
#
#                                              summary  \
# 0           Quiet Garden View Room & Super Fast WiFi
# 1  You will love our spacious (90 m2) bright apar...
# ...

# %%
# Drop columns
df_ld= df_ld.drop(columns=['listing_url', 'scrape_id', 'last_scraped', 'host_id', 'host_url', 'host_name', 'host_since', 'host_location',
'host_about', 'host_response_time', 'host_response_rate','host_acceptance_rate','notes', 'transit', 'interaction', 'thumbnail_url', 'medium_url',
'xl_picture_url', 'picture_url', 'host_picture_url', 'first_review', 'last_review',
'jurisdiction_names', 'instant_bookable', 'is_business_travel_ready',
'require_guest_profile_picture', 'require_guest_phone_verification',
'host_thumbnail_url', 'host_neighbourhood', 'host_listings_count',
'host_total_listings_count', 'host_verifications', 'host_has_profile_pic',
'host_identity_verified', 'summary', 'listing_url', 'description',
'house_rules', 'picture_url', 'market', 'calendar_last_scraped',
'reviews_per_month', 'neighbourhood_group_cleansed', 'square_feet', 'license'])

# %%
df_ld.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20030 entries, 0 to 20029
# Data columns (total 53 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20030 non-null  int64
#  1   name                            19992 non-null  object
#  2   space                           14579 non-null  object
#  3   experiences_offered             20030 non-null  object
#  4   neighborhood_overview           13257 non-null  object
#  5   access                          12227 non-null  object
#  6   host_is_superhost               20026 non-null  object
#  7   street                          20030 non-null  object
#  8   neighbourhood                   18377 non-null  object
#  9   neighbourhood_cleansed          20030 non-null  object
#  10  city                            20026 non-null  object
#  11  state                           19903 non-null  object
# ...

# %%
df_ld.tail()
# Out:
#              id                                              name  \
# 20025  30576148  Family House City + free Parking+garden (160 m2)
# 20026  30577727                 Home Sweet Home in Indische Buurt
# 20027  30578037            Amsterdam Cozy apartment nearby center
# 20028  30579673           Home Sweet Home for a Guest or a Couple
# 20029  30580413       Cosy two bedroom appartment near 'de Pijp'!
#
#                                                    space experiences_offered  \
# 20025  Our house is a spacious family house, just ren...                none
# 20026  We have fluffy bedsheets and cozy lighning. Th...                none
# 20027                                                NaN                none
# 20028  There are fluffy bedsheets and cozy lightning....                none
# 20029                                                NaN                none
#
#                                    neighborhood_overview  \
# ...

# %%
# save data changes
df_calendar.to_csv(os.path.join(path, 'Data','Prepared Data', 'calendar_cleaned.csv'))

# %%
df.to_csv(os.path.join(path, 'Data','Prepared Data', 'listings_cleaned.csv'))

# %%
df_ld.to_csv(os.path.join(path, 'Data','Prepared Data', 'listings_details_cleaned.csv'))

# %%
df_reviews.to_csv(os.path.join(path, 'Data','Prepared Data', 'reviews_cleaned.csv'))

# %%
df_reviewsdetails.to_csv(os.path.join(path, 'Data','Prepared Data', 'reviews_details_cleaned.csv'))

# %%
df_neigbor.to_csv(os.path.join(path, 'Data','Prepared Data', 'reviews_neighborhood_cleaned.csv'))

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.info()
#
# NameError: name 'df' is not defined
